# %%
import networkx as nx
import re
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout
import os
import numpy as np
import pandas as pd
from networkx.algorithms.shortest_paths.generic import shortest_path_length

# %%
def read_file(filename):
    with open(filename, 'r') as f:
        doc = f.read()
        sentences = re.split('\.|\?|!', doc)
    data = [];
    for s in sentences:
        temp = re.split('\W+',s)
        temp = list(filter(lambda a: a != '', temp))
        temp = [t.lower() for t in temp]
        data.append(temp)
    return(data)
def read_directory(directory):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            filename = directory + '/' + filename
            temp = read_file(filename)
            for t in temp: 
                data.append(t)
    return(data)

# %%
def gen_graph(data):
    G = nx.Graph()
    for s in data:
        prev_word = None
        for word in s:
            if not word in list(G.nodes):
                G.add_node(word)
            if prev_word:
                if not (prev_word,word) in list(G.edges):
                    G.add_edge(prev_word,word)
            prev_word = word
    return(G)
def findResSet(T):
    degs = T.degree()
    root = 0
    path = -1
    for k in degs:
        if k[1] > 1: root = k[0]
        if k[1] > 2:
            path = -1
            break
        if k[1] <= 1: path = k[0]
    if path != -1: return ({}, [path])

    (L, um, _) = partitionLeaves(T, node=root)
    R = []
    for h in L:
        if len(L[h]) > 0:
            i = np.random.choice(len(L[h]))
            R.extend(L[h][:i] + L[h][i+1:])
    return (L, R)

def partitionLeaves(T, node=0,  parent=-1):
    (marked, unmarked, last) = ({}, [], -1)
    N = T.degree(node)
    if N == 1: return (marked, [node], last)
    if N >= 3:
        marked[node] = []
        last = node
    children = [n for n in T.neighbors(node) if n!=parent]
    for child in children:
        (m, um, l) = partitionLeaves(T, node=child, parent=node)
        marked.update(m)
        if len(um) > 0 and N >= 3: marked[node].extend(um)
        else:
            unmarked.extend(um)
            last = l 
    if len(unmarked) > 0 and last != -1: marked[last].extend(unmarked)
    return (marked, unmarked, last)
def distanceMatrix(G):
    keys = list(G.nodes)
    dist_mat = pd.DataFrame()

# %%
def approxGraphMetricDim(G, fullMatrix=True, distance=-1, name='', read_state='', randOrder=True, procs=1):
    check = sorted(G.nodes())
    if fullMatrix:
        D = []
        if distance==-1 or distance>1:
            D = nx.all_pairs_shortest_path_length(G, cutoff=(None if distance==-1 else distance))
            if distance==-1: D = [[D[i].get(j, -1) if i in D else -1 for j in check] for i in check]
            if distance>1: D = [[min(D[i].get(j, distance) if i in D else distance, distance) for j in check] for i in check]
        elif distance==1:
            D = [[1 if j in G.neighbors(i) else 0 for j in check] for i in check]
        return approxMetricDim(D, name=name, read_state=read_state, randOrder=randOrder, procs=procs)
    progress_file = name+'_progress.txt'
    distr = {}
    tags = ['' for _ in xrange(len(check))]
    chosen = []
    if read_state:
        (tags, chosen) = readState(read_state)
        for i in xrange(len(tags)):
            if tags[i] not in distr: distr[tags[i]] = []
            distr[tags[i]].append(i)
    elif name: saveState([], [], progress_file, overwrite=True)
    n = len(G)
    H = 0
    while len(distr) < n and len(chosen) < n:#
        (distr, tags, H, chosen) = pickGraphColumn(G, tags, check, chosen=chosen, distance=distance, procs=procs)
        check.remove(chosen[-1])
        if name: saveState(tags, chosen, progress_file, overwrite=True)
    if len(distr) < n and len(chosen) == n: print('No solution exists', distr)
    return chosen

# %%
directory = "test_files"
data = read_directory(directory)
G = gen_graph(data)

# %%
tree = nx.maximum_spanning_tree(G)

# %%
(L, R) = findResSet(tree)
print(L)
# Out:
# {'order': ['displays', 'hang', 'enter', 'ready', 'bring', 'flow', 'these', 'charging', 'james', 'wider', 'cadillac', 'vary', 'ot', 'friends', 'medium', 'completed', 'mother', 'put', '95', 'received', 'corrected', 'wrong', 'tough', 'structure', 'careful', 'purse'], 'almost': ['pulled', 'payed', '90', 'point', 'anywhere', 'mention', '9', 'decadent', 'steal', 'doing', 'licked', 'zero', 'overcooked'], 'same': ['smell', 'salt', 'remains', 'faces', 'palace', 'floor', 'tolerable', 'league', 'variety', 'turkey', 'applebees', 'screaming', 'reale', 'spot', 'halibut'], 'still': ['contact', 'brenner', 'edible', 'biggie', 'waiting', 'youre', 'pleased', 'supervisors', 'marks', 'missing', 'screens'], 'somewhat': ['obtrusively', 'gal'], 'giving': ['flat', 'unwarranted'], 'made': ['multi', 'reservations', 'jason', 'matt', 'flakes', 'evidently', 'fyi', 'fro', 'worker', 'cinnamon', 'glaze', 'blunder'], 'lemon': ['doused', 'viniagrette', 'vinegar'], 'table': ['periodic', 'elements', 'escorted', 'handfuls', 'checkered', 'cloths', 'settings', 'points', 'substitute', 'approaches', 'struggled'], 'see': ['nye', 'afc'], 'vegas': ['claimed', 'blvd', 'ceasar', 'figured', 'constantly', 'native', 'baby', 'seven', 'thus', 'hunt', 'whenever', 'omgah', 'standards', 'finden', 'priced', 'obvious', 'article', 'bought', 'boulevard', 'situated', 'page', 'highly', 'dawned', 'welcome', 'nonetheless', 'pacific', 'visitors'], 'joe': ['passed', 'compete'], 'say': ['needless', 'embarrassing', 'previously'], 'tasted': ['deliscious', 'ocean'], 'visit': ['repeated', 'latest'], 'every': ['inept', 'acceptability'], 'nothing': ['bizarre', 'longing', 'memorable', 'suppose', 'worry', 'beats'], 'happened': ['finding', 'investigate', 'fiancee'], 'good': ['hollywood', 'otherwise', 'loyal', 'company', 'weeks', 'prix', 'start', 'tooo', 'twin', 'pay', 'presence', 'true', 'croutons', 'soups', 'calamri', 'damn', 'smokes', 'cuz', 'meant', 'feta', 'venue', 'forming', 'reported', 'is', 'him', 'cobbler', 'assume', 'knowing', 'killer', 'crumble', 'blunt', 'except', 'drawn', 'dam', 'expecting', 'mexican'], 'considering': ['steep', 'breaded'], 'perfectly': ['dente', 'seared', 'girlfriend'], 'too': ['project', 'cookie'], 'getting': ['lucky', 'keeping', 'differently'], 'dining': ['tired', 'brulees'], 'tables': ['occupied', 'multiple', 'receive', 'gamble'], 'system': ['gastrointestinal', 'deeply'], 'thanks': ['eta', 'o', 'elisa'], '20': ['roam', '000'], 'take': ['gulps', 'advantage', 'sonics', 'forever', 'seat'], 'steak': ['somehow', 'oz', 'complement', 'frite', 'turf', 'array', '48', 'skewers', '18oz', 'dc', 'stomach', 'satays'], 'man': ['lady', 'rocked', 'ooooooooo'], 'two': ['forgetting', 'seemingly', 'mates', 'roughly', 'tiniest', 'after', 'decently', 'quotations', 'conversation', 'babbling', 'nights', 'of', 'select', 'separate', 'process'], 'noticed': ['nevertheless', 'charged', 'inauspiciously'], 'because': ['evil', 'flight', 'serrated', 'drunken', 'existent', 'actor', 'word', 'alcoholic', 'tartare', 'lucked', 'score', 'crumbs', 'seats', 'hi', 'funny'], 'lobster': ['blt', 'lightly', 'sweetness', 'fiance', 'misheard'], 'gave': ['ladies', 'martinez'], 'oysters': ['wow', 'carlton', 'cents', 'pointe', 'columbia', 'loves', 'newcastle', 'sprinkle', 'river', 'kusshi', 'dozens', 'wkday', 'equivalent', 'clams', 'shrimps', 'seattle', 'bc', 'british', 'dirty', 'va', 'beach', 'shortlist', 'sampling', 'laguna', 'becasue', 'prelude'], 'more': ['wishes', 'weighing', 'cognac', 'intrigued', 'dissappointing', 'noodles', 'acidity', 'widescreen', 'weight', 'quieter', 'touristy', 'carrying', 'hyped', 'eagle', 'personal'], 'just': ['ignored', 'pretending', 'series', 'simplicity', 'sucky', 'figure', 'couldnt', 'post', 'signed', 'traditional', 'boiled', 'raisins', 'cranberry', 'sang', 'aiming', 'totts', 'lighting', 'ps', '19', 'opened', 'consistently', 'plates', 'skating', 'palm', 'inside', 'honest', 'overwhelming', 'addresses', 'dropped', 'plain', 'chardonnay', 'disappointment', 'pile', 'ordinary', 'branch', 'hu ...

# %%
print(R)
# Out:
# ['hang', 'enter', 'ready', 'bring', 'flow', 'these', 'charging', 'james', 'wider', 'cadillac', 'vary', 'ot', 'friends', 'medium', 'completed', 'mother', 'put', '95', 'received', 'corrected', 'wrong', 'tough', 'structure', 'careful', 'purse', 'pulled', 'payed', '90', 'point', 'anywhere', 'mention', '9', 'decadent', 'steal', 'doing', 'licked', 'zero', 'smell', 'salt', 'remains', 'faces', 'palace', 'floor', 'tolerable', 'league', 'variety', 'turkey', 'applebees', 'screaming', 'reale', 'spot', 'brenner', 'edible', 'biggie', 'waiting', 'youre', 'pleased', 'supervisors', 'marks', 'missing', 'screens', 'gal', 'unwarranted', 'multi', 'reservations', 'jason', 'matt', 'flakes', 'evidently', 'fyi', 'fro', 'worker', 'cinnamon', 'glaze', 'doused', 'vinegar', 'periodic', 'elements', 'handfuls', 'checkered', 'cloths', 'settings', 'points', 'substitute', 'approaches', 'struggled', 'nye', 'claimed', 'blvd', 'ceasar', 'figured', 'constantly', 'native', 'baby', 'seven', 'thus', 'hunt', 'whenever', 'omgah', 'standards', 'finden', 'priced', 'obvious', 'article', 'bought', 'boulevard', 'situated', 'page', 'highly', 'dawned', 'welcome', 'pacific', 'visitors', 'compete', 'needless', 'previously', 'ocean', 'repeated', 'inept', 'bizarre', 'longing', 'suppose', 'worry', 'beats', 'finding', 'investigate', 'hollywood', 'otherwise', 'loyal', 'company', 'weeks', 'prix', 'start', 'tooo', 'twin', 'pay', 'presence', 'true', 'croutons', 'soups', 'damn', 'smokes', 'cuz', 'meant', 'feta', 'venue', 'forming', 'reported', 'is', 'him', 'cobbler', 'assume', 'knowing', 'killer', 'crumble', 'blunt', 'except', 'drawn', 'dam', 'expecting', 'mexican', 'steep', 'seared', 'girlfriend', 'cookie', 'keeping', 'differently', 'tired', 'occupied', 'multiple', 'gamble', 'deeply', 'eta', 'o', 'roam', 'advantage', 'sonics', 'forever', 'seat', 'somehow', 'oz', 'complement', 'turf', 'array', '48', 'skewers', '18oz', 'dc', 'stomach', 'satays', 'rocked', 'ooooooooo', 'forgetting', 'seemingly', 'mates', 'roughly', 'tiniest', 'after', 'decently', 'quotations', 'conversation', 'nights', 'of', 'select', 'separate', 'process', 'charged', 'inauspiciously', 'evil', 'flight', 'serrated', 'drunken', 'existent', 'actor', 'word', 'alcoholic', 'tartare', 'score', 'crumbs', 'seats', 'hi', 'funny', 'blt', 'lightly', 'sweetness', 'misheard', 'martinez', 'wow', 'carlton', 'cents', 'pointe', 'columbia', 'loves', 'sprinkle', 'river', 'kusshi', 'dozens', 'wkday', 'equivalent', 'clams', 'shrimps', 'seattle', 'bc', 'british', 'dirty', 'va', 'beach', 'shortlist', 'sampling', 'laguna', 'becasue', 'prelude', 'wishes', 'weighing', 'cognac', 'intrigued', 'dissappointing', 'noodles', 'acidity', 'widescreen', 'weight', 'touristy', 'carrying', 'hyped', 'eagle', 'personal', 'ignored', 'pretending', 'series', 'simplicity', 'sucky', 'figure', 'couldnt', 'post', 'signed', 'traditional', 'raisins', 'cranberry', 'sang', 'aiming', 'totts', 'lighting', 'ps', '19', 'opened', 'consistently', 'plates', 'skating', 'palm', 'inside', 'honest', 'overwhelming', 'addresses', 'dropped', 'plain', 'chardonnay', 'disappointment', 'pile', 'ordinary', 'branch', 'hubbub', 'hubby', 'chilling', 'similarly', 'hasbrown', 'guy', 'stuck', 'paid', 'cilantro', 'writing', 'customize', 'mazing', 'herbsaint', 'and14', 'predictably', 'fixe', 'discuss', 'appointment', 'fixed', 'occasion', 'shame', 'lovely', 'favorites', 'story', 'sticker', 'board', 'states', 'lite', 'reads', 'choose', 'given', 'sort', 'nasty', 'effort', 'tuesdays', 'martini', 'indication', 'whatsoever', 'cozy', 'private', 'compensation', 'broken', 'unlike', 'longer', 'responsible', 'marketing', 'werent', 'saltiness', 'dab', 'lisa', 'initiative', 'apologizing', 'tablecloth', 'bottled', 'admitting', 'jelly', 'spend', 'status', 'forums', 'treat', 'field', 'tongue', 'pricing', 'melt', 'pays', 'fist', 'thumb', 'eight', 'save', 'aphrodisiacstic', 'choosing', 'blow', 'upset', 'villa', 'weren', 'won', 'eats', 'foodwriters', 'obviously', 'presented', 'bivalves', 'certain', 'rarely', 'fit', 'we ...

# %%
nx.draw(G)
plt.show()

# %%
data = [['hello', 'i', 'am', 'busy', 'with', 'school'], ['who', 'am', 'i', 'meeting', 'today']]
temp = gen_graph(data)
nx.draw(temp, with_labels = True)
plt.show()

# %%
print(len(G.nodes))
print(len(R))
# Out:
# 3871
# 2450
